# %% [markdown]
# ## 📌 Project Ka Simple Matlab:
#
# Ye project ek aisa model banata hai jo **kisi bhi sentence ke next word ko predict (batane)** ki koshish karta hai.
# Jaise agar aap likho _“To be or not to”_, to model batayega agla word kya ho sakta hai.
#
# ---
#
# ## 🔍 Step by Step Simple Explanation:
#
# ### 1. **Data Collection (Data jama karna):**
# Shakespeare ke famous drama **"Hamlet"** ka text liya gaya.
# Ye thoda tough aur classic English hoti hai — isse model ko acchi training milti hai.
#
# ---
#
# ### 2. **Data Preprocessing (Data ko prepare karna):**
# - Text ko words me tod diya gaya (**tokenization**)
# - Sentence ko numbers me convert kiya gaya
# - Sabhi sequences ko same length banane ke liye **padding** kiya
# - Phir data ko **training** aur **testing** me divide kar diya
#
# ---
#
# ### 3. **Model Building (Model banana):**
# - Pehle ek **embedding layer** use ki gayi jo words ko numbers me samajhne me help karti hai
# - Fir 2 **LSTM layers** use ki gayi
#   (ye memory rakhne wale special layer hote hain, jo sequence ka meaning samajhte hain)
# - Last me ek **dense layer with softmax** lagaya gaya jo agla word predict karta hai
#
# ---
#
# ### 4. **Model Training (Model ko sikhana):**
# - Model ko data se train kiya gaya
# - **Early stopping** ka use kiya — agar model **overfit** ho raha ho ya improve na ho raha ho to training ruk jaati hai
#
# ---
#
# ### 5. **Model Evaluation (Model ka test):**
# - Kuch **example sentences** ke sath check kiya gaya ki model kitna sahi predict kar raha hai
#
# ---
#
# ### 6. **Deployment (Use karne layak banana):**
# - Ek **Streamlit app** banayi gayi jisme aap koi sentence likh sakte ho
# - App batata hai ki uske baad ka likely **next word** kya ho sakta hai — **live prediction** hota hai!
#
# ---
#
# ### ✅ Agar ek line me bolu to:
#
# > Ye project ek **smart AI model** banata hai jo aapke likhe sentence ka **agla word guess** karta hai,
# > aur aap ise ek website (**Streamlit app**) pe try kar sakte ho.
