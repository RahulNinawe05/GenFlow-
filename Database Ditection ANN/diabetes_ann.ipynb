# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input , Dropout
from pathlib import Path

# %%
path = Path("D:/LC-basics[0]/Database Ditection ANN/diabetes.csv")
df = pd.read_csv(path)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
print(df.head(5))
print("-----------")
print(df.shape)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# -----------
# (768, 9)

# %%
X = df.drop('Outcome',axis=1)
Y = df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y,
    test_size=0.2,
    random_state=42
)

# %%
scaler = StandardScaler()

X_train =  scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.52639686, -1.15139792, -3.75268255, ..., -4.13525578,
#         -0.49073479, -1.03594038],
#        [ 1.58804586, -0.27664283,  0.68034485, ..., -0.48916881,
#          2.41502991,  1.48710085],
#        [-0.82846011,  0.56687102, -1.2658623 , ..., -0.42452187,
#          0.54916055, -0.94893896],
#        ...,
#        [ 1.8901091 , -0.62029661,  0.89659009, ...,  1.76054443,
#          1.981245  ,  0.44308379],
#        [-1.13052335,  0.62935353, -3.75268255, ...,  1.34680407,
#         -0.78487662, -0.33992901],
#        [-1.13052335,  0.12949347,  1.43720319, ..., -1.22614383,
#         -0.61552223, -1.03594038]], shape=(614, 8))

# %%
X_test
# Out:
# array([[ 0.68185612, -0.71402038, -0.61712658, ...,  0.26073561,
#         -0.11637247,  0.87809089],
#        [-0.52639686, -0.27664283,  0.30191569, ...,  0.48053518,
#         -0.954231  , -1.03594038],
#        [-0.52639686, -0.40160784, -0.29275872, ..., -0.15300476,
#         -0.9245197 , -1.03594038],
#        ...,
#        [ 1.28598261, -0.80774414,  0.13973176, ...,  0.62275843,
#          0.04703966,  2.0961108 ],
#        [-0.52639686,  0.78555979,  0.03160914, ..., -0.51502758,
#         -0.39268751, -0.33992901],
#        [ 1.28598261, -1.46381046,  0.03160914, ...,  0.42881763,
#          0.70068816,  0.53008521]], shape=(154, 8))

# %%
model = Sequential([
    # shape
    Input(shape=(8,)),
    # input layer
    Dense(16, activation='relu'),
    Dropout(0.3),

    # heddin layer
    Dense(8, activation='relu'),
    Dropout(0.2),

    # output layer
    Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,           # 50 baar data dekhega
    batch_size=32,       # ek baar mein 32 samples
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.4664 - loss: 0.7639 - val_accuracy: 0.5528 - val_loss: 0.6603
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5173 - loss: 0.6984 - val_accuracy: 0.6748 - val_loss: 0.6398
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6090 - loss: 0.6762 - val_accuracy: 0.7073 - val_loss: 0.6245
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6090 - loss: 0.6539 - val_accuracy: 0.7317 - val_loss: 0.6127
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6314 - loss: 0.6476 - val_accuracy: 0.7561 - val_loss: 0.6038
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6599 - loss: 0.6243 - val_accuracy: 0.7561 - val_loss: 0.5976
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6843 - loss: 0.6177 - val_accuracy: 0.7398 - val_loss: 0.5920
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6741 - loss: 0.6091 - val_accuracy: 0.7398 - val_loss: 0.5863
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7026 - loss: 0.5925 - val_accuracy: 0.7398 - val_loss: 0.5812
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6986 - loss: 0.6010 - val_accuracy: 0.7317 - val_loss: 0.5764
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7128 - loss: 0.5779 - val_accuracy: 0.7398 - val_loss: 0.5698
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7230 - loss: 0.5604 - val_accuracy: 0.7317 - val_loss: 0.5661
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7271 - loss: 0.5804 - val_accuracy: 0.7236 - val_loss: 0.5612
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7128 - loss: 0.5637 - val_accuracy: 0.7317 - val_loss: 0.5557
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.5420 - val_accuracy: 0.7317 - val_loss: 0.5511
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7617 - loss: 0.5457 - val_accuracy: 0.7398 - val_loss: 0.5473
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7352 - loss: 0.5611 - val_accuracy: 0.7398 - val_loss: 0.5433
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7495 - loss: 0.5442 - val_accuracy: 0.7236 - val_loss: 0.5391
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7149 - loss: 0.5539 - val_accuracy: 0.7236 - val_loss: 0.5364
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7291 - loss: 0.5386 - val_accuracy: 0.7236 - val_loss: 0.5343
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7536 - loss: 0.5323 - val_accuracy: 0.7154 - val_loss: 0.5309
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7556 - loss: 0.5178 - val_accuracy: 0.7154 - val_loss: 0.5256
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7515 - loss: 0.5119 - val_accuracy: 0.7154 - val_loss: 0.5214
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7332 - loss: 0.5488 - val_accuracy: 0.7154 - val_loss: 0.5183
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7576 - loss: 0.5351 - val_accuracy: 0.7236 - val_loss: 0.5176
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7699 - loss: 0.5217 - val_accuracy: 0.7398 - val_loss: 0.5150
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7332 - loss: 0.5246 - val_accuracy: 0.7480 - val_loss: 0.5150
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.5189 - val_accuracy: 0.7398 - val_loss: 0.5129
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7393 - loss: 0.5038 - val_accuracy: 0.7398 - val_loss: 0.5106
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7475 - loss: 0.5295 - val_accuracy: 0.7398 - val_loss: 0.5094
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7576 - loss: 0.5214 - val_accuracy: 0.7480 - val_loss: 0.5091
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7515 - loss: 0.5024 - val_accuracy: 0.7561 - val_loss: 0.5084
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7434 - loss: 0.5241 - val_accuracy: 0.7561 - val_loss: 0.5041
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7515 - loss: 0.5193 - val_accuracy: 0.7480 - val_loss: 0.5014
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7597 - loss: 0.5037 - val_accuracy: 0.7642 - val_loss: 0.5010
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.4909 - val_accuracy: 0.7480 - val_loss: 0.4987
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7760 - loss: 0.4971 - val_accuracy: 0.7480 - val_loss: 0.4965
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7556 - loss: 0.4922 - val_accuracy: 0.7480 - val_loss: 0.4943
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7760 - loss: 0.4891 - val_accuracy: 0.7398 - val_loss: 0.4925
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7617 - loss: 0.4995 - val_accuracy: 0.7398 - val_loss: 0.4920
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7393 - loss: 0.5121 - val_accuracy: 0.7561 - val_loss: 0.4922
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7637 - loss: 0.4975 - val_accuracy: 0.7561 - val_loss: 0.4917
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7576 - loss: 0.5065 - val_accuracy: 0.7561 - val_loss: 0.4918
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7617 - loss: 0.5038 - val_accuracy: 0.7561 - val_loss: 0.4912
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7780 - loss: 0.4886 - val_accuracy: 0.7480 - val_loss: 0.4904
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7739 - loss: 0.4937 - val_accuracy: 0.7561 - val_loss: 0.4893
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7495 - loss: 0.5022 - val_accuracy: 0.7561 - val_loss: 0.4864
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7597 - loss: 0.4875 - val_accuracy: 0.7561 - val_loss: 0.4865
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7719 - loss: 0.4746 - val_accuracy: 0.7561 - val_loss: 0.4850
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7821 - loss: 0.4866 - val_accuracy: 0.7561 - val_loss: 0.4848

# %%
new_patient = np.array([[8, 183, 64, 0, 0, 23.3, 0.672, 32]])

# Scale karo
new_patient = scaler.transform(new_patient)

# Predict karo
prediction = model.predict(new_patient)

if prediction[0][0] > 0.5:
    print("⚠️  Diabetes HAI!")
else:
    print("✅ Diabetes NAHI hai!")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# ⚠️  Diabetes HAI!
# d:\LC-basics[0]\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
