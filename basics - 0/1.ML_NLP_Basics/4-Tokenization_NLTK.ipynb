# %% [markdown]
# ## Tokenization in NLP (Natural Language Toolkit)
# means breaking a text into smaller parts (called tokens). In most cases, these tokens are words or sentences.
#
# ## What is Tokenization in NLP?
# **Tokenization is the process of splitting text into smaller pieces, called tokens.**
# ### These tokens can be:
# - Words → word-level tokenization
# - Characters → character-level tokenization
# - Subwords → subword tokenization (e.g., Byte-Pair Encoding)
# - Sentences → sentence-level tokenization

# %%
# pip install nltk

# %%
corpus = """Hello My Name 😂 is #Rahul Ninawe, I Like to Learn $Machine Learning. I Love it to Much..."""

# %%
print(corpus)
# Out:
# Hello My Name 😂 is #Rahul Ninawe, I Like to Learn $Machine Learning. I Love it to Much...

# %%
corpus
# Out:
# 'Hello My Name 😂 is #Rahul Ninawe, I Like to Learn $Machine Learning. I Love it to Much...'

# %%
# formal text, split  "#" 
# Used in Documents/articals
from nltk.tokenize import word_tokenize 
x = word_tokenize(corpus)

# %%
x
# Out:
# ['Hello',
#  'My',
#  'Name',
#  '😂',
#  'is',
#  '#',
#  'Rahul',
#  'Ninawe',
#  ',',
#  'I',
#  'Like',
#  'to',
#  'Learn',
#  '$',
#  'Machine',
#  'Learning',
#  '.',
#  'I',
#  'Love',
#  'it',
#  'to',
#  'Much',
#  '...']

# %%
from nltk.tokenize import sent_tokenize
y = sent_tokenize(corpus)

# %%
y
# Out:
# ['Hello My Name 😂 is #Rahul Ninawe, I Like to Learn $Machine Learning.',
#  'I Love it to Much...']

# %%
# Social Meadia, Preserved  "#" 
# Used in Char/instagram/tweets
from nltk.tokenize import casual_tokenize
r = casual_tokenize(corpus)

# %%
print(r)
# Out:
# ['Hello', 'My', 'Name', '😂', 'is', '#Rahul', 'Ninawe', ',', 'I', 'Like', 'to', 'Learn', '$', 'Machine', 'Learning', '.', 'I', 'Love', 'it', 'to', 'Much', '...']

# %% [markdown]
# ### TreebankWordTokenizer =
# - **tokenizer for formal, well-written English text**
# - **It splits punctuation and contractions accurately**
# - **Useful for tasks like POS tagging, parsing, and formal NLP tasks**

# %%
from nltk.tokenize import TreebankWordTokenizer # similar to word_tokenizer
toke_nise = TreebankWordTokenizer()
tok = toke_nise.tokenize(corpus)

# %%
tok
# Out:
# ['Hello',
#  'My',
#  'Name',
#  '😂',
#  'is',
#  '#',
#  'Rahul',
#  'Ninawe',
#  ',',
#  'I',
#  'Like',
#  'to',
#  'Learn',
#  '$',
#  'Machine',
#  'Learning.',
#  'I',
#  'Love',
#  'it',
#  'to',
#  'Much',
#  '...']
