# %%
corpus = """
Sindhutai Sapkal was born on November 14, 1948, in a poor family in Maharashtra.
She faced discrimination as a girl and struggled to get an education.
Her father supported her secretly to study, even though her mother opposed it.
She was married off at the age of 12 to a man 20 years older.
Her life after marriage was filled with hardships and abuse.
At the age of 20, she was abandoned by her husband while pregnant.
She gave birth in a cowshed, all alone and helpless.
Left with nothing, she began begging at railway stations and temples.
During this time, she saw many orphaned children suffering like her.
She started adopting and caring for these orphans as her own children.
Over time, she became known as the “Mother of Orphans.”
She raised more than 1,500 orphaned children throughout her life.
To support them, she gave speeches and used the money to feed them.
She turned her pain into a mission of love, strength, and care.
Her work received national recognition and many awards, including the Padma Shri.
Sindhutai’s story is a true example of courage, compassion, and selfless service.
---"""

# %%
new_thing  =corpus.split()
new_thing
# Out:
# ['Sindhutai',
#  'Sapkal',
#  'was',
#  'born',
#  'on',
#  'November',
#  '14,',
#  '1948,',
#  'in',
#  'a',
#  'poor',
#  'family',
#  'in',
#  'Maharashtra.',
#  'She',
#  'faced',
#  'discrimination',
#  'as',
#  'a',
#  'girl',
#  'and',
#  'struggled',
#  'to',
#  'get',
#  'an',
#  'education.',
#  'Her',
#  'father',
#  'supported',
#  'her',
#  'secretly',
#  'to',
#  'study,',
#  'even',
#  'though',
#  'her',
#  'mother',
#  'opposed',
#  'it.',
#  'She',
#  'was',
#  'married',
#  'off',
#  'at',
#  'the',
#  'age',
#  'of',
#  '12',
#  'to',
#  'a',
#  'man',
#  '20',
#  'years',
#  'older.',
#  'Her',
#  'life',
#  'after',
#  'marriage',
#  'was',
#  'filled',
#  'with',
#  'hardships',
#  'and',
#  'abuse.',
#  'At',
#  'the',
#  'age',
#  'of',
#  '20,',
#  'she',
#  'was',
#  'abandoned',
#  'by',
#  'her',
#  'husband',
#  'while',
#  'pregnant.',
#  'She',
#  'gave',
#  'birth',
#  'in',
#  'a',
#  'cowshed,',
#  'all',
#  'alone',
#  'and',
#  'helpless.',
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

stemmer = PorterStemmer()

Porter_Stemmer= stemmer.stem(corpus)

# %%
from nltk.tokenize import sent_tokenize
import nltk

senetence_token = sent_tokenize(corpus)
type(senetence_token)
# Out:
# list

# %%
# # Apply Stowords And Filtter And then Apply Stemming

# for i in range(len(senetence_token)):
#     words = nltk.word_tokenize(senetence_token[i])
#     words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('English'))]
#     senetence_token[i]= ' '.join(words)

# %%
# senetence_token

# %%
for i in range(len(senetence_token)):
    element = nltk.word_tokenize(senetence_token[i])
    element =[stemmer.stem(data) for data in element if data not in set(stopwords.words('english'))]
    senetence_token[i] = ' '.join(element)

# %%
senetence_token

# %%
from nltk.stem import SnowballStemmer

SnowballStemmer = SnowballStemmer('english')

# %%
for i in range(len(senetence_token)):
    data = nltk.word_tokenize(senetence_token[i])
    data = [SnowballStemmer.stem(word) for word in data if word not in set(stopwords.words('english'))]
    senetence_token[i]= ' '.join(data)

# %%
senetence_token

# %%
# use pos in detaisl

for i in range(len(senetence_token)):
    info= nltk.word_tokenize(senetence_token[i])
    info =[data for data in info if data not in set(stopwords.words('english'))]
    potag = nltk.pos_tag(info)
    print(potag)
# Out:
# [('sindhutai', 'NN'), ('sapkal', 'NN'), ('born', 'VBN'), ('novemb', 'RB'), ('14', 'CD'), (',', ','), ('1948', 'CD'), (',', ','), ('poor', 'JJ'), ('famili', 'NN'), ('maharashtra', 'NN'), ('.', '.')]
# [('face', 'NN'), ('discrimin', 'NN'), ('girl', 'NN'), ('struggl', 'NN'), ('get', 'VB'), ('educ', 'NN'), ('.', '.')]
# [('father', 'NN'), ('support', 'NN'), ('secret', 'JJ'), ('studi', 'NN'), (',', ','), ('even', 'RB'), ('though', 'IN'), ('mother', 'NN'), ('oppo', 'NN'), ('.', '.')]
# [('marri', 'NN'), ('age', 'NN'), ('12', 'CD'), ('man', 'NN'), ('20', 'CD'), ('year', 'NN'), ('older', 'NN'), ('.', '.')]
# [('life', 'NN'), ('marriag', 'NN'), ('fill', 'NN'), ('hardship', 'NN'), ('abus', 'NN'), ('.', '.')]
# [('age', 'NN'), ('20', 'CD'), (',', ','), ('abandon', 'JJ'), ('husband', 'NN'), ('pregnant', 'NN'), ('.', '.')]
# [('gave', 'VBD'), ('birth', 'NN'), ('cowsh', 'NN'), (',', ','), ('alon', 'NN'), ('helpless', 'NN'), ('.', '.')]
# ...

# %%
for i in range(len(senetence_token)):
    data = nltk.word_tokenize(senetence_token[i])
    data = [word for word in data if word not in set(stopwords.words('french'))]
    pos=nltk.pos_tag(data)
    print(pos)
# Out:
# [('sindhutai', 'NN'), ('sapkal', 'NN'), ('born', 'VBN'), ('novemb', 'RB'), ('14', 'CD'), (',', ','), ('1948', 'CD'), (',', ','), ('poor', 'JJ'), ('famili', 'NN'), ('maharashtra', 'NN'), ('.', '.')]
# [('face', 'NN'), ('discrimin', 'NN'), ('girl', 'NN'), ('struggl', 'NN'), ('get', 'VB'), ('educ', 'NN'), ('.', '.')]
# [('father', 'NN'), ('support', 'NN'), ('secret', 'JJ'), ('studi', 'NN'), (',', ','), ('even', 'RB'), ('though', 'IN'), ('mother', 'NN'), ('oppo', 'NN'), ('.', '.')]
# [('marri', 'NN'), ('age', 'NN'), ('12', 'CD'), ('man', 'NN'), ('20', 'CD'), ('year', 'NN'), ('older', 'NN'), ('.', '.')]
# [('life', 'NN'), ('marriag', 'NN'), ('fill', 'NN'), ('hardship', 'NN'), ('abus', 'NN'), ('.', '.')]
# [('age', 'NN'), ('20', 'CD'), (',', ','), ('abandon', 'JJ'), ('husband', 'NN'), ('pregnant', 'NN'), ('.', '.')]
# [('gave', 'VBD'), ('birth', 'NN'), ('cowsh', 'NN'), (',', ','), ('alon', 'NN'), ('helpless', 'NN'), ('.', '.')]
# ...

# %%
sentence = "Elon Musk, the CEO of Tesla, earned $10 billion in 2021 and held a meeting at 3:00 PM on Monday in California."

# %%
word_token = nltk.word_tokenize(sentence)

# %%
tag_pos=nltk.pos_tag(word_token)

# %%
word_to= nltk.word_tokenize(corpus)

# %%
response  = nltk.pos_tag(word_to)

# %%
! pip install svgling

# %%
import nltk

# %%
# import sys
# !{sys.executable} -m pip install svgling
# Out:
# ...
#   Using cached svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Using cached svgling-0.5.0-py3-none-any.whl (31 kB)
# Using cached svgwrite-1.4.3-py3-none-any.whl (67 kB)
# ...
#
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    ---------------------------------------- 0/2 [svgwrite]
#    -------------------- ------------------- 1/2 [svgling]
#    -------------------- ------------------- 1/2 [svgling]
# ...

# %%
s = nltk.ne_chunk(response)
# print(s) # deffencece is this (text formate)
s
# Out:
# Tree('S', [Tree('PERSON', [('Sindhutai', 'NNP')]), Tree('PERSON', [('Sapkal', 'NNP')]), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('November', 'NNP'), ('14', 'CD'), (',', ','), ('1948', 'CD'), (',', ','), ('in', 'IN'), ('a', 'DT'), ('poor', 'JJ'), ('family', 'NN'), ('in', 'IN'), Tree('GPE', [('Maharashtra', 'NNP')]), ('.', '.'), ('She', 'PRP'), ('faced', 'VBD'), ('discrimination', 'NN'), ('as', 'IN'), ('a', 'DT'), ('girl', 'NN'), ('and', 'CC'), ('struggled', 'VBD'), ('to', 'TO'), ('get', 'VB'), ('an', 'DT'), ('education', 'NN'), ('.', '.'), ('Her', 'PRP$'), ('father', 'NN'), ('supported', 'VBD'), ('her', 'PRP$'), ('secretly', 'RB'), ('to', 'TO'), ('study', 'VB'), (',', ','), ('even', 'RB'), ('though', 'IN'), ('her', 'PRP$'), ('mother', 'NN'), ('opposed', 'VBD'), ('it', 'PRP'), ('.', '.'), ('She', 'PRP'), ('was', 'VBD'), ('married', 'VBN'), ('off', 'RP'), ('at', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('12', 'CD'), ('to', 'TO'), ('a', 'DT'), ('man', 'NN'), ('20', 'CD')
# ...

# %%
import pandas as pd
pd.read_csv()
